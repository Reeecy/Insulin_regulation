# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
import pandas as pd
import numpy as np
import sys

# %%
# Load the data
data = pd.read_csv('../data/559-full.csv')
data.head()
data.tail()
# Out:
#              timestamp  glucose_level  exercise_today  sleep_last_night  \
# 13305  1/27/2022 23:18            185             265               0.0
# 13306  1/27/2022 23:23            183             265               0.0
# 13307  1/27/2022 23:28            182             265               0.0
# 13308  1/27/2022 23:33            180             265               0.0
# 13309  1/27/2022 23:38            177             265               0.0
#
#        last_meal_time  last_meal_time_carbs  last_basal_time  \
# 13305        6.300000                  45.0        50.300000
# 13306        6.383333                  45.0        50.383333
# 13307        6.466667                  45.0        50.466667
# 13308        6.550000                  45.0        50.550000
# 13309        6.633333                  45.0        50.633333
#
#        last_basal_value  last_bolus_time  last_bolus_value  last_bolus_carbs
# 13305              1.25         1.183889               4.0              34.0
# ...

# %%
# Code cleanup
data.dropna(inplace=True)

data.drop(['timestamp'], inplace=True, axis=1)

data.head()
# Out:
#      glucose_level  exercise_today  sleep_last_night  last_meal_time  \
# 170            110               0              24.0        0.033333
# 171            106               0              24.0        0.116667
# 172             99               0              24.0        0.200000
# 173             97               0              24.0        0.283333
# 174             97               0              24.0        0.366667
#
#      last_meal_time_carbs  last_basal_time  last_basal_value  last_bolus_time  \
# 170                  18.0         4.450000               0.9         4.086389
# 171                  18.0         4.533333               0.9         4.169722
# 172                  18.0         4.616667               0.9         4.253056
# 173                  18.0         4.700000               0.9         4.336389
# 174                  18.0         4.783333               0.9         4.419722
#
#      last_bolus_value  last_bolus_carbs
# 170               9.3               0.0
# ...

# %%
X = data.drop('glucose_level', axis=1)
Y = data['glucose_level']

print(X.shape, Y.shape)
# Out:
# (10527, 9) (10527,)

# %%
# Split the data
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=32)

# %%
# Train the model
#regr = RandomForestRegressor(max_depth=3, random_state=5)
regr = RandomForestRegressor()
regr.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
# Predict

y_pred = regr.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print(f'mse: {mse}\nr2: {r2}')
# Out:
# mse: 62.42062697056031
# r2: 0.9877391054442598

# %%
row = 1
test_data = {'exercise_today': [0], 'sleep_last_night': [30], 'last_meal_time': [0.116666667], 'last_meal_time_carbs': [18], 'last_basal_time': [4.533333333], 'last_basal_value': [0.9], 'last_bolus_time': [4.169722222], 'last_bolus_value': [5], 'last_bolus_carbs': [5]}
new_data = pd.DataFrame(test_data)
new_row = pd.DataFrame([data.iloc[row].drop('glucose_level')])
prediction = regr.predict(new_data)
value = data.iloc[row]['glucose_level']
print(f'Prediction: {prediction}\nValue: {value}')
# Out:
# Prediction: [158.8]
# Value: 106.0

# %%
# Save the model
import joblib
joblib.dump(regr, 'model.pkl')

# %%
# Load the model
regr = joblib.load('model.pkl')
